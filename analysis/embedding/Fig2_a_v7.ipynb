# %%
import pandas as pd

# %%
# %run analysis_utils.py

# %%
# def map_groups(exp):

#     if 'gf' in exp:
#         return 'Geneformer'
#     elif 'Geneformer' in exp:
#         return 'Geneformer'
#     elif 'scfoundation' in exp:
#         return 'Other'
#     elif 'scimilarity' in exp:
#         return 'Other'
#     elif 'scgpt' in exp:
#         return 'scGPT'
#     elif 'cellplm' in exp:
#         return 'Other'
    
#     elif any(x in exp for x in ['hvg', 'pca', 'scvi']):
#         return 'Baseline'
#     else:
#         return 'Other'  # optional fallback

# %%
model_name_map={
'hvg': 'HVG',
'pca': 'PCA',
'scgpt': 'scGPT', 
'scgpt_cancer': 'scGPT [cancer]',
'scvi':'scVI',
'scvi_donor_id':'scVI',
'scfoundation':'scFoundation',
'scimilarity':'SCimiarity',
'cellplm':'CellPLM',
'gf-6L-30M-i2048': 'GF-V1',
'gf-6L-30M-i2048_continue': 'GF-V1 [continue]',
'Geneformer-V2-104M_CLcancer': 'GF-V2 [cancer]',
'Geneformer-V2-104M': 'GF-V2',
'Geneformer-V2-104M_continue': 'GF-V2 [continue]',
'Geneformer-V2-316M': 'GF-V2-Deep',
'gf-6L-30M-i2048_finetune': 'GF-V1 [finetune]',
'Geneformer-V2-104M_finetune': 'GF-V2 [finetune]',
'hvg_seurat_4096': 'HVG' ,                        
'state_se600m_epoch16': 'STATE',                     
'scfoundation_brca_cancer_cells': 'scFoundation',         
'geneformer_V2-104M_CLcancer-i4096':'GF-V2 [cancer]',
'geneformer_V2-316M-i4096':'GF-V2-Deep'                    , 
'continue_geneformer_V1-10M-i2048_continue':'GF-V1 [continue]',     
'geneformer_V1-10M-i2048':'GF-V1'       ,
'continue_geneformer_V2-104M-i4096_continue': 'GF-V2 [continue]'  ,  
'geneformer_V2-104M-i4096': 'GF-V2'                 ,
'scgpt_cancer-i2048' :'scGPT [cancer]',                           
'scgpt_human-i2048'  : 'scGPT',                          
'cellplm_85M-20231027'  :'CellPLM',                       
'scimilarity_v1.1': 'SCimiarity'                              ,
'pca_n100'  :'PCA [100]'                                ,
'pca_n50'   : 'PCA [50]',                                   
'pca_n20'                : 'PCA [20]'        ,               
'scvi'                               :'scVI'     ,      
'scconcept_corpus30m' : 'scConcept'                          ,
'nicheformer_nicheformer'                       :'Nicheformer',


}

# %%
import os
results_path = os.path.abspath('./results/all_results.csv')

# %%
results_10_runs = pd.read_csv(results_path)

# %%
results_10_runs['method'] = results_10_runs['model']

# %%
results_10_runs
# Out:
#      run                    model  NMI_cluster/label  ARI_cluster/label  \
# 0      0          hvg_seurat_4096           0.727366           0.665796
# 1      1          hvg_seurat_4096           0.714877           0.654820
# 2      2          hvg_seurat_4096           0.720390           0.660523
# 3      3          hvg_seurat_4096           0.721569           0.670643
# 4      4          hvg_seurat_4096           0.735398           0.677316
# ..   ...                      ...                ...                ...
# 165    5  nicheformer_nicheformer           0.098089           0.073527
# 166    6  nicheformer_nicheformer           0.094947           0.066759
# 167    7  nicheformer_nicheformer           0.061519           0.071537
# 168    8  nicheformer_nicheformer           0.064199           0.072174
# 169    9  nicheformer_nicheformer           0.088515           0.073270
#
#      ASW_label  graph_conn  ASW_batch  ASW_label/batch  batch_ASW  PCR_batch  \
# 0     0.517525    0.983183   0.475448         0.942540   0.942540   0.201333
# 1     0.516845    0.977675   0.476484         0.931721   0.931721   0.202841
# 2     0.517481    0.981039   0.476495         0.931486   0.931486   0.200860
# 3     0.517861    0.971821   0.474983         0.934361   0.934361   0.201534
# 4     0.517153    0.980973   0.473647         0.935889   0.935889   0.202307
# ..         ...         ...        ...              ...        ...        ...
# 165   0.430256    0.759765   0.429837         0.851248   0.851248   0.052553
# 166   0.458579    0.816308   0.429846         0.828524   0.828524   0.050141
# 167   0.437003    0.818978   0.429928         0.836562   0.836562   0.052106
# 168   0.434666    0.761041   0.428069         0.851266   0.851266   0.050826
# 169   0.458343    0.764718   0.422811         0.832552   0.832552   0.052175
#
#         iLISI     cLISI      kBET   avg_bio  knn_label_purity  \
# 0    0.027189  1.000000  0.512754  0.636896          0.957867
# 1    0.026069  1.000000  0.413550  0.628847          0.957400
# 2    0.028659  1.000000  0.531328  0.632798          0.956827
# 3    0.027581  1.000000  0.382888  0.636691          0.952220
# 4    0.029358  1.000000  0.509024  0.643289          0.956993
# ..        ...       ...       ...       ...               ...
# 165  0.045079  0.934176  0.567059  0.200624          0.588953
# 166  0.044832  0.934008  0.569731  0.206762          0.582760
# 167  0.044714  0.934831  0.556432  0.190020          0.589240
# 168  0.045165  0.934964  0.548152  0.190346          0.588727
# 169  0.044935  0.934005  0.554644  0.206709          0.586493
#
#      knn_batch_purity  batch_pred_acc  kNN_label_acc  kNN_label_f1_macro  \
# 0            0.415560          0.3200         0.9245            0.909779
# 1            0.414553          0.3195         0.8995            0.907264
# 2            0.413713          0.3105         0.9130            0.912007
# 3            0.410107          0.2930         0.8990            0.899312
# 4            0.413920          0.3180         0.9100            0.898508
# ..                ...             ...            ...                 ...
# 165          0.139400          0.1535         0.6775            0.440338
# 166          0.139373          0.1480         0.6740            0.424586
# 167          0.140393          0.1440         0.6890            0.454958
# 168          0.139420          0.1410         0.6875            0.446156
# 169          0.139313          0.1560         0.6855            0.434409
#
#                       method
# 0            hvg_seurat_4096
# 1            hvg_seurat_4096
# 2            hvg_seurat_4096
# 3            hvg_seurat_4096
# 4            hvg_seurat_4096
# ..                       ...
# 165  nicheformer_nicheformer
# 166  nicheformer_nicheformer
# 167  nicheformer_nicheformer
# 168  nicheformer_nicheformer
# 169  nicheformer_nicheformer
#
# [170 rows x 20 columns]

# %%
results_10_runs.model.value_counts()
# Out:
# model
# hvg_seurat_4096                               10
# state_se600m_epoch16                          10
# scfoundation_brca_cancer_cells                10
# geneformer_V2-104M_CLcancer-i4096             10
# geneformer_V2-316M-i4096                      10
# continue_geneformer_V1-10M-i2048_continue     10
# geneformer_V1-10M-i2048                       10
# continue_geneformer_V2-104M-i4096_continue    10
# geneformer_V2-104M-i4096                      10
# scgpt_cancer-i2048                            10
# scgpt_human-i2048                             10
# cellplm_85M-20231027                          10
# scimilarity_v1.1                              10
# pca_n100                                      10
# pca_n50                                       10
# pca_n20                                       10
# scvi                                          10
# scconcept_corpus30m                           10
# nicheformer_nicheformer                       10
# Name: count, dtype: int64

# %%
len(results_10_runs.model.unique())
# Out:
# 17

# %%
# ind = results_10_runs.method=='scvi'
# results_10_runs = results_10_runs[~ind]

# %%
# ind = results_10_runs.method.str.startswith('__')
# results_10_runs = results_10_runs[~ind]

# %%
# results_10_runs.model.value_counts()

# %%
# results_10_runs['group'] =  results_10_runs['model']

# %%
results_10_runs['group'] =  results_10_runs['model'].map(map_groups)

# %%
results_10_runs['model'] =  results_10_runs['model'].map(model_name_map)

# %%
results_10_runs.model.value_counts()
# Out:
# model
# HVG                 10
# STATE               10
# scFoundation        10
# GF-V2 [cancer]      10
# GF-V2-Deep          10
# GF-V1 [continue]    10
# GF-V1               10
# GF-V2 [continue]    10
# GF-V2               10
# scGPT [cancer]      10
# scGPT               10
# CellPLM             10
# SCimiarity          10
# PCA [100]           10
# scVI                10
# Nicheformer         10
# Name: count, dtype: int64

# %%
results_10_runs
# Out:
#      run        model  NMI_cluster/label  ARI_cluster/label  ASW_label  \
# 0      0          HVG           0.727366           0.665796   0.517525
# 1      1          HVG           0.714877           0.654820   0.516845
# 2      2          HVG           0.720390           0.660523   0.517481
# 3      3          HVG           0.721569           0.670643   0.517861
# 4      4          HVG           0.735398           0.677316   0.517153
# ..   ...          ...                ...                ...        ...
# 165    5  Nicheformer           0.098089           0.073527   0.430256
# 166    6  Nicheformer           0.094947           0.066759   0.458579
# 167    7  Nicheformer           0.061519           0.071537   0.437003
# 168    8  Nicheformer           0.064199           0.072174   0.434666
# 169    9  Nicheformer           0.088515           0.073270   0.458343
#
#      graph_conn  ASW_batch  ASW_label/batch  batch_ASW  PCR_batch  ...  \
# 0      0.983183   0.475448         0.942540   0.942540   0.201333  ...
# 1      0.977675   0.476484         0.931721   0.931721   0.202841  ...
# 2      0.981039   0.476495         0.931486   0.931486   0.200860  ...
# 3      0.971821   0.474983         0.934361   0.934361   0.201534  ...
# 4      0.980973   0.473647         0.935889   0.935889   0.202307  ...
# ..          ...        ...              ...        ...        ...  ...
# 165    0.759765   0.429837         0.851248   0.851248   0.052553  ...
# 166    0.816308   0.429846         0.828524   0.828524   0.050141  ...
# 167    0.818978   0.429928         0.836562   0.836562   0.052106  ...
# 168    0.761041   0.428069         0.851266   0.851266   0.050826  ...
# 169    0.764718   0.422811         0.832552   0.832552   0.052175  ...
#
#         cLISI      kBET   avg_bio  knn_label_purity  knn_batch_purity  \
# 0    1.000000  0.512754  0.636896          0.957867          0.415560
# 1    1.000000  0.413550  0.628847          0.957400          0.414553
# 2    1.000000  0.531328  0.632798          0.956827          0.413713
# 3    1.000000  0.382888  0.636691          0.952220          0.410107
# 4    1.000000  0.509024  0.643289          0.956993          0.413920
# ..        ...       ...       ...               ...               ...
# 165  0.934176  0.567059  0.200624          0.588953          0.139400
# 166  0.934008  0.569731  0.206762          0.582760          0.139373
# 167  0.934831  0.556432  0.190020          0.589240          0.140393
# 168  0.934964  0.548152  0.190346          0.588727          0.139420
# 169  0.934005  0.554644  0.206709          0.586493          0.139313
#
#      batch_pred_acc  kNN_label_acc  kNN_label_f1_macro  \
# 0            0.3200         0.9245            0.909779
# 1            0.3195         0.8995            0.907264
# 2            0.3105         0.9130            0.912007
# 3            0.2930         0.8990            0.899312
# 4            0.3180         0.9100            0.898508
# ..              ...            ...                 ...
# 165          0.1535         0.6775            0.440338
# 166          0.1480         0.6740            0.424586
# 167          0.1440         0.6890            0.454958
# 168          0.1410         0.6875            0.446156
# 169          0.1560         0.6855            0.434409
#
#                       method     group
# 0            hvg_seurat_4096  Baseline
# 1            hvg_seurat_4096  Baseline
# 2            hvg_seurat_4096  Baseline
# 3            hvg_seurat_4096  Baseline
# 4            hvg_seurat_4096  Baseline
# ..                       ...       ...
# 165  nicheformer_nicheformer     Other
# 166  nicheformer_nicheformer     Other
# 167  nicheformer_nicheformer     Other
# 168  nicheformer_nicheformer     Other
# 169  nicheformer_nicheformer     Other
#
# [170 rows x 21 columns]

# %%
save_path= os.path.abspath('./results/all_results_dashboard.csv')
results_10_runs.to_csv(save_path)

# %%
# results_10_runs = results_10_runs[results_10_runs['method'] != 'GF-V2 [continue]']

# %%
nmi_df = results_10_runs[['model', 'NMI_cluster/label', 'group']].copy()
nmi_df.columns= ['model', 'NMI', 'group']

# %%
ari_df = results_10_runs[['model', 'ARI_cluster/label', 'group']].copy()
ari_df.columns= ['model', 'ARI', 'group']

# %%
asw_df = results_10_runs[['model', 'ASW_label', 'group']].copy()
asw_df.columns= ['model', 'ASW', 'group']

# %%
# nmi_df['method'] =  nmi_df['method'].map(model_name_map)

# %%
# nmi_df['method'] = nmi_df['method'].map(model_name_map)

# %%
nmi_df
# Out:
#            model       NMI     group
# 0            HVG  0.727366  Baseline
# 1            HVG  0.714877  Baseline
# 2            HVG  0.720390  Baseline
# 3            HVG  0.721569  Baseline
# 4            HVG  0.735398  Baseline
# ..           ...       ...       ...
# 165  Nicheformer  0.098089     Other
# 166  Nicheformer  0.094947     Other
# 167  Nicheformer  0.061519     Other
# 168  Nicheformer  0.064199     Other
# 169  Nicheformer  0.088515     Other
#
# [170 rows x 3 columns]

# %%
nmi_df.group.unique()
# Out:
# array(['Baseline', 'Other', 'Geneformer', 'scGPT'], dtype=object)

# %%
group= 'scGPT'

# %%
subset = nmi_df[nmi_df['group'] == group].copy()

# %%
subset
# Out:
#               model       NMI  group
# 100  scGPT [cancer]  0.784938  scGPT
# 101  scGPT [cancer]  0.774543  scGPT
# 102  scGPT [cancer]  0.781632  scGPT
# 103  scGPT [cancer]  0.815514  scGPT
# 104  scGPT [cancer]  0.780328  scGPT
# 105  scGPT [cancer]  0.789351  scGPT
# 106  scGPT [cancer]  0.775566  scGPT
# 107  scGPT [cancer]  0.782399  scGPT
# 108  scGPT [cancer]  0.788297  scGPT
# 109  scGPT [cancer]  0.776524  scGPT
# 110           scGPT  0.737661  scGPT
# 111           scGPT  0.725801  scGPT
# 112           scGPT  0.752997  scGPT
# 113           scGPT  0.740557  scGPT
# 114           scGPT  0.716663  scGPT
# 115           scGPT  0.732172  scGPT
# 116           scGPT  0.709779  scGPT
# 117           scGPT  0.738283  scGPT
# 118           scGPT  0.702018  scGPT
# 119           scGPT  0.736341  scGPT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

def plot_metric_by_group_violin(df, metric_col="NMI_cluster/label", title=None, ylim=(0.4, 0.8)):
    """
    Plots a violin plot of the specified metric for each group, with adaptive subplot widths.
    
    Parameters:
    - df (pd.DataFrame): Input DataFrame with columns 'group', 'method', and the metric.
    - metric_col (str): Column name of the metric to plot.
    - title (str): Optional title for the entire plot.
    - ylim (tuple): Y-axis limits.
    """

    sns.set(style="whitegrid")

    # Get unique groups and method counts
    group_method_counts = df.groupby("group")["model"].nunique()
    total_methods = group_method_counts.sum()

    # Set up figure and grid
    fig = plt.figure(figsize=(6 * len(group_method_counts) / 2, 6))
    gs = gridspec.GridSpec(1, len(group_method_counts), width_ratios=group_method_counts.values, figure=fig)

    for idx, (group, method_count) in enumerate(group_method_counts.items()):
        ax = fig.add_subplot(gs[0, idx])
        subset = df[df['group'] == group].copy()

        # Sort methods by median
        method_stats = subset.groupby("model")[metric_col].median().sort_values(ascending=True)
        ordered_methods = method_stats.index.tolist()
        subset["model"] = pd.Categorical(subset["model"], categories=ordered_methods, ordered=True)

        # Violin plot
        sns.violinplot(
            data=subset,
            x="model",
            y=metric_col,
            ax=ax,
            inner="quartile",
            scale="area",
            width=0.5
        )

        # Line plot for group medians
        stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
        ax.plot(range(len(ordered_methods)), stat_values, marker='o', linestyle='--', color='black', label='Median')

        ax.set_title(f"{group}")
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
        ax.set_xlabel('')
        ax.set_ylim(*ylim)
        if idx != 0:
            ax.set_yticklabels([])
            ax.set_ylabel("")

    # Final layout and title
    plot_title = title or f"{metric_col} Distribution by Method (Grouped)"
    fig.suptitle(plot_title, fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    # plt.show()
    return fig

# %%
group_method_counts = nmi_df.groupby("group")["model"].nunique()
group_method_counts
# Out:
# group
# Baseline      3
# Geneformer    6
# Other         5
# scGPT         2
# Name: model, dtype: int64

# %%
group_method_counts.sort_values(ascending=False)
# Out:
# group
# Geneformer    6
# Other         5
# Baseline      3
# scGPT         2
# Name: model, dtype: int64

# %%
nmi_df[nmi_df.model=='scFoundation']
# Out:
#            model       NMI  group
# 20  scFoundation  0.711266  Other
# 21  scFoundation  0.735855  Other
# 22  scFoundation  0.724782  Other
# 23  scFoundation  0.752089  Other
# 24  scFoundation  0.727215  Other
# 25  scFoundation  0.737498  Other
# 26  scFoundation  0.707562  Other
# 27  scFoundation  0.723343  Other
# 28  scFoundation  0.733933  Other
# 29  scFoundation  0.745383  Other

# %%
fig = plot_metric_by_group_violin(nmi_df, metric_col="NMI", ylim=(0.0, 1.))
plt.savefig('./plots/nmi3.png', dpi=100)
# Out:
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
kNN_label_f1_macro = results_10_runs[['model', 'kNN_label_f1_macro', 'group']].copy()
kNN_label_f1_macro.columns= ['model', 'F1', 'group']

fig = plot_metric_by_group_violin(kNN_label_f1_macro, metric_col="F1", ylim=(0.0, 1.))
plt.savefig('./plots/kNN_label_f1_macro.png', dpi=100)
# Out:
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig = plot_metric_by_group_violin(ari_df, metric_col="ARI", ylim=(0.0, 1.))
plt.savefig('./plots/ari3.png', dpi=100)
# Out:
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig = plot_metric_by_group_violin(asw_df, metric_col="ASW", ylim=(0.48, .7))
plt.savefig('./plots/asw3.png', dpi=100)
# Out:
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_659461/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_659461/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_659461/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
