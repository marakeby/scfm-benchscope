# %%
import pandas as pd

# %%
# %run analysis_utils.py

# %%
# def map_groups(exp):

#     if 'gf' in exp:
#         return 'Geneformer'
#     elif 'Geneformer' in exp:
#         return 'Geneformer'
#     elif 'scfoundation' in exp:
#         return 'Other'
#     elif 'scimilarity' in exp:
#         return 'Other'
#     elif 'scgpt' in exp:
#         return 'scGPT'
#     elif 'cellplm' in exp:
#         return 'Other'
    
#     elif any(x in exp for x in ['hvg', 'pca', 'scvi']):
#         return 'Baseline'
#     else:
#         return 'Other'  # optional fallback

# %%
model_name_map={
'hvg': 'HVG',
'pca': 'PCA',
'scgpt': 'scGPT', 
'scgpt_cancer': 'scGPT [cancer]',
'scvi':'scVI',
'scvi_donor_id':'scVI',
'scfoundation':'scFoundation',
'scimilarity':'SCimiarity',
'cellplm':'CellPLM',
'gf-6L-30M-i2048': 'GF-V1',
'gf-6L-30M-i2048_continue': 'GF-V1 [continue]',
'Geneformer-V2-104M_CLcancer': 'GF-V2 [cancer]',
'Geneformer-V2-104M': 'GF-V2',
'Geneformer-V2-104M_continue': 'GF-V2 [continue]',
'Geneformer-V2-316M': 'GF-V2-Deep',
'gf-6L-30M-i2048_finetune': 'GF-V1 [finetune]',
'Geneformer-V2-104M_finetune': 'GF-V2 [finetune]',
'hvg_seurat_4096': 'HVG' ,                        
'state_se600m_epoch16': 'STATE',                     
'scfoundation_brca_cancer_cells': 'scFoundation',         
'geneformer_V2-104M_CLcancer-i4096':'GF-V2 [cancer]',
'geneformer_V2-316M-i4096':'GF-V2-Deep'                    , 
'continue_geneformer_V1-10M-i2048_continue':'GF-V1 [continue]',     
'geneformer_V1-10M-i2048':'GF-V1'       ,
'continue_geneformer_V2-104M-i4096_continue': 'GF-V2 [continue]'  ,  
'geneformer_V2-104M-i4096': 'GF-V2'                 ,
'scgpt_cancer-i2048' :'scGPT [cancer]',                           
'scgpt_human-i2048'  : 'scGPT',                          
'cellplm_85M-20231027'  :'CellPLM',                       
'scimilarity_v1.1': 'SCimiarity'                              ,
'pca_n100'  :'PCA [100]'                                ,
'pca_n50'   : 'PCA [50]',                                   
'pca_n20'                : 'PCA [20]'        ,               
'scvi'                               :'scVI'     ,      
'scconcept_corpus30m' : 'scConcept'                          ,
'nicheformer_nicheformer'                       :'Nicheformer',


}

# %%
import os
results_path = os.path.abspath('./results/all_results.csv')

# %%
results_10_runs = pd.read_csv(results_path)

# %%
results_10_runs['method'] = results_10_runs['model']

# %%
results_10_runs
# Out:
#      run                    model  NMI_cluster/label  ARI_cluster/label  \
# 0      0          hvg_seurat_4096           0.624315           0.373985
# 1      1          hvg_seurat_4096           0.610604           0.350091
# 2      2          hvg_seurat_4096           0.609138           0.348967
# 3      3          hvg_seurat_4096           0.603086           0.342048
# 4      4          hvg_seurat_4096           0.609030           0.350927
# ..   ...                      ...                ...                ...
# 185    5  nicheformer_nicheformer           0.363442           0.292557
# 186    6  nicheformer_nicheformer           0.406932           0.307163
# 187    7  nicheformer_nicheformer           0.345295           0.268186
# 188    8  nicheformer_nicheformer           0.348658           0.260438
# 189    9  nicheformer_nicheformer           0.391628           0.276720
#
#      ASW_label  graph_conn  ASW_batch  ASW_label/batch  batch_ASW  PCR_batch  \
# 0     0.508810    0.988908   0.481371         0.950398   0.950398   0.221653
# 1     0.508840    0.991525   0.481384         0.951645   0.951645   0.218747
# 2     0.509000    0.988757   0.481385         0.951300   0.951300   0.219299
# 3     0.509227    0.989168   0.481284         0.950802   0.950802   0.220736
# 4     0.509186    0.985225   0.481075         0.951190   0.951190   0.219747
# ..         ...         ...        ...              ...        ...        ...
# 185   0.476198    0.946583   0.448007         0.876247   0.876247   0.080889
# 186   0.477860    0.939009   0.447095         0.880821   0.880821   0.080531
# 187   0.481411    0.907834   0.449767         0.868320   0.868320   0.078127
# 188   0.479306    0.915494   0.444825         0.888451   0.888451   0.079003
# 189   0.476707    0.927540   0.446706         0.886372   0.886372   0.079934
#
#         iLISI     cLISI      kBET   avg_bio  knn_label_purity  \
# 0    0.036385  1.000000  0.498102  0.502370          0.932527
# 1    0.034821  1.000000  0.501899  0.489845          0.937620
# 2    0.035745  1.000000  0.467512  0.489035          0.933773
# 3    0.035225  1.000000  0.473735  0.484787          0.937300
# 4    0.034229  1.000000  0.478870  0.489714          0.931173
# ..        ...       ...       ...       ...               ...
# 185  0.053971  0.994551  0.591862  0.377399          0.772533
# 186  0.053348  0.993795  0.569174  0.397318          0.770167
# 187  0.053463  0.993973  0.567564  0.364964          0.771420
# 188  0.053448  0.992944  0.583399  0.362800          0.762233
# 189  0.053196  0.993549  0.609125  0.381685          0.764453
#
#      knn_batch_purity  batch_pred_acc  kNN_label_acc  kNN_label_f1_macro  \
# 0            0.449733          0.3805         0.8265            0.864096
# 1            0.453947          0.3860         0.8255            0.839069
# 2            0.453007          0.3795         0.8175            0.870441
# 3            0.452527          0.3870         0.8690            0.911825
# 4            0.451180          0.3590         0.8320            0.883732
# ..                ...             ...            ...                 ...
# 185          0.241853          0.3105         0.8265            0.746862
# 186          0.244553          0.3160         0.8315            0.765878
# 187          0.239260          0.2895         0.8210            0.751540
# 188          0.241480          0.2995         0.8105            0.715134
# 189          0.241253          0.2980         0.8195            0.803030
#
#                       method
# 0            hvg_seurat_4096
# 1            hvg_seurat_4096
# 2            hvg_seurat_4096
# 3            hvg_seurat_4096
# 4            hvg_seurat_4096
# ..                       ...
# 185  nicheformer_nicheformer
# 186  nicheformer_nicheformer
# 187  nicheformer_nicheformer
# 188  nicheformer_nicheformer
# 189  nicheformer_nicheformer
#
# [190 rows x 20 columns]

# %%
results_10_runs.model.value_counts()
# Out:
# model
# hvg_seurat_4096                               10
# state_se600m_epoch16                          10
# scfoundation_brca_cancer_cells                10
# geneformer_V2-104M_CLcancer-i4096             10
# geneformer_V2-316M-i4096                      10
# continue_geneformer_V1-10M-i2048_continue     10
# geneformer_V1-10M-i2048                       10
# continue_geneformer_V2-104M-i4096_continue    10
# geneformer_V2-104M-i4096                      10
# scgpt_cancer-i2048                            10
# scgpt_human-i2048                             10
# cellplm_85M-20231027                          10
# scimilarity_v1.1                              10
# pca_n100                                      10
# pca_n50                                       10
# pca_n20                                       10
# scvi                                          10
# scconcept_corpus30m                           10
# nicheformer_nicheformer                       10
# Name: count, dtype: int64

# %%
len(results_10_runs.model.unique())
# Out:
# 19

# %%
# ind = results_10_runs.method=='scvi'
# results_10_runs = results_10_runs[~ind]

# %%
# ind = results_10_runs.method.str.startswith('__')
# results_10_runs = results_10_runs[~ind]

# %%
# results_10_runs.model.value_counts()

# %%
# results_10_runs['group'] =  results_10_runs['model']

# %%
results_10_runs['group'] =  results_10_runs['model'].map(map_groups)

# %%
results_10_runs['model'] =  results_10_runs['model'].map(model_name_map)

# %%
results_10_runs.model.value_counts()
# Out:
# model
# HVG                 10
# STATE               10
# scFoundation        10
# GF-V2 [cancer]      10
# GF-V2-Deep          10
# GF-V1 [continue]    10
# GF-V1               10
# GF-V2 [continue]    10
# GF-V2               10
# scGPT [cancer]      10
# scGPT               10
# CellPLM             10
# SCimiarity          10
# PCA [100]           10
# PCA [50]            10
# PCA [20]            10
# scVI                10
# scConcept           10
# Nicheformer         10
# Name: count, dtype: int64

# %%
results_10_runs
# Out:
#      run        model  NMI_cluster/label  ARI_cluster/label  ASW_label  \
# 0      0          HVG           0.624315           0.373985   0.508810
# 1      1          HVG           0.610604           0.350091   0.508840
# 2      2          HVG           0.609138           0.348967   0.509000
# 3      3          HVG           0.603086           0.342048   0.509227
# 4      4          HVG           0.609030           0.350927   0.509186
# ..   ...          ...                ...                ...        ...
# 185    5  Nicheformer           0.363442           0.292557   0.476198
# 186    6  Nicheformer           0.406932           0.307163   0.477860
# 187    7  Nicheformer           0.345295           0.268186   0.481411
# 188    8  Nicheformer           0.348658           0.260438   0.479306
# 189    9  Nicheformer           0.391628           0.276720   0.476707
#
#      graph_conn  ASW_batch  ASW_label/batch  batch_ASW  PCR_batch  ...  \
# 0      0.988908   0.481371         0.950398   0.950398   0.221653  ...
# 1      0.991525   0.481384         0.951645   0.951645   0.218747  ...
# 2      0.988757   0.481385         0.951300   0.951300   0.219299  ...
# 3      0.989168   0.481284         0.950802   0.950802   0.220736  ...
# 4      0.985225   0.481075         0.951190   0.951190   0.219747  ...
# ..          ...        ...              ...        ...        ...  ...
# 185    0.946583   0.448007         0.876247   0.876247   0.080889  ...
# 186    0.939009   0.447095         0.880821   0.880821   0.080531  ...
# 187    0.907834   0.449767         0.868320   0.868320   0.078127  ...
# 188    0.915494   0.444825         0.888451   0.888451   0.079003  ...
# 189    0.927540   0.446706         0.886372   0.886372   0.079934  ...
#
#         cLISI      kBET   avg_bio  knn_label_purity  knn_batch_purity  \
# 0    1.000000  0.498102  0.502370          0.932527          0.449733
# 1    1.000000  0.501899  0.489845          0.937620          0.453947
# 2    1.000000  0.467512  0.489035          0.933773          0.453007
# 3    1.000000  0.473735  0.484787          0.937300          0.452527
# 4    1.000000  0.478870  0.489714          0.931173          0.451180
# ..        ...       ...       ...               ...               ...
# 185  0.994551  0.591862  0.377399          0.772533          0.241853
# 186  0.993795  0.569174  0.397318          0.770167          0.244553
# 187  0.993973  0.567564  0.364964          0.771420          0.239260
# 188  0.992944  0.583399  0.362800          0.762233          0.241480
# 189  0.993549  0.609125  0.381685          0.764453          0.241253
#
#      batch_pred_acc  kNN_label_acc  kNN_label_f1_macro  \
# 0            0.3805         0.8265            0.864096
# 1            0.3860         0.8255            0.839069
# 2            0.3795         0.8175            0.870441
# 3            0.3870         0.8690            0.911825
# 4            0.3590         0.8320            0.883732
# ..              ...            ...                 ...
# 185          0.3105         0.8265            0.746862
# 186          0.3160         0.8315            0.765878
# 187          0.2895         0.8210            0.751540
# 188          0.2995         0.8105            0.715134
# 189          0.2980         0.8195            0.803030
#
#                       method     group
# 0            hvg_seurat_4096  Baseline
# 1            hvg_seurat_4096  Baseline
# 2            hvg_seurat_4096  Baseline
# 3            hvg_seurat_4096  Baseline
# 4            hvg_seurat_4096  Baseline
# ..                       ...       ...
# 185  nicheformer_nicheformer     Other
# 186  nicheformer_nicheformer     Other
# 187  nicheformer_nicheformer     Other
# 188  nicheformer_nicheformer     Other
# 189  nicheformer_nicheformer     Other
#
# [190 rows x 21 columns]

# %%
save_path= os.path.abspath('./results/all_results_dashboard.csv')
results_10_runs.to_csv(save_path)

# %%
# results_10_runs = results_10_runs[results_10_runs['method'] != 'GF-V2 [continue]']

# %%
nmi_df = results_10_runs[['model', 'NMI_cluster/label', 'group']].copy()
nmi_df.columns= ['model', 'NMI', 'group']

# %%
ari_df = results_10_runs[['model', 'ARI_cluster/label', 'group']].copy()
ari_df.columns= ['model', 'ARI', 'group']

# %%
asw_df = results_10_runs[['model', 'ASW_label', 'group']].copy()
asw_df.columns= ['model', 'ASW', 'group']

# %%
# nmi_df['method'] =  nmi_df['method'].map(model_name_map)

# %%
# nmi_df['method'] = nmi_df['method'].map(model_name_map)

# %%
nmi_df
# Out:
#            model       NMI     group
# 0            HVG  0.624315  Baseline
# 1            HVG  0.610604  Baseline
# 2            HVG  0.609138  Baseline
# 3            HVG  0.603086  Baseline
# 4            HVG  0.609030  Baseline
# ..           ...       ...       ...
# 185  Nicheformer  0.363442     Other
# 186  Nicheformer  0.406932     Other
# 187  Nicheformer  0.345295     Other
# 188  Nicheformer  0.348658     Other
# 189  Nicheformer  0.391628     Other
#
# [190 rows x 3 columns]

# %%
nmi_df.group.unique()
# Out:
# array(['Baseline', 'Other', 'Geneformer', 'scGPT'], dtype=object)

# %%
group= 'scGPT'

# %%
subset = nmi_df[nmi_df['group'] == group].copy()

# %%
subset
# Out:
#               model       NMI  group
# 90   scGPT [cancer]  0.710309  scGPT
# 91   scGPT [cancer]  0.713568  scGPT
# 92   scGPT [cancer]  0.764968  scGPT
# 93   scGPT [cancer]  0.763803  scGPT
# 94   scGPT [cancer]  0.752068  scGPT
# 95   scGPT [cancer]  0.774882  scGPT
# 96   scGPT [cancer]  0.772071  scGPT
# 97   scGPT [cancer]  0.775198  scGPT
# 98   scGPT [cancer]  0.750406  scGPT
# 99   scGPT [cancer]  0.756447  scGPT
# 100           scGPT  0.693099  scGPT
# 101           scGPT  0.691939  scGPT
# 102           scGPT  0.744270  scGPT
# 103           scGPT  0.719437  scGPT
# 104           scGPT  0.694732  scGPT
# 105           scGPT  0.753912  scGPT
# 106           scGPT  0.700507  scGPT
# 107           scGPT  0.738063  scGPT
# 108           scGPT  0.735009  scGPT
# 109           scGPT  0.749721  scGPT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

def plot_metric_by_group_violin(df, metric_col="NMI_cluster/label", title=None, ylim=(0.4, 0.8)):
    """
    Plots a violin plot of the specified metric for each group, with adaptive subplot widths.
    
    Parameters:
    - df (pd.DataFrame): Input DataFrame with columns 'group', 'method', and the metric.
    - metric_col (str): Column name of the metric to plot.
    - title (str): Optional title for the entire plot.
    - ylim (tuple): Y-axis limits.
    """

    sns.set(style="whitegrid")

    # Get unique groups and method counts
    group_method_counts = df.groupby("group")["model"].nunique()
    total_methods = group_method_counts.sum()

    # Set up figure and grid
    fig = plt.figure(figsize=(6 * len(group_method_counts) / 2, 6))
    gs = gridspec.GridSpec(1, len(group_method_counts), width_ratios=group_method_counts.values, figure=fig)

    for idx, (group, method_count) in enumerate(group_method_counts.items()):
        ax = fig.add_subplot(gs[0, idx])
        subset = df[df['group'] == group].copy()

        # Sort methods by median
        method_stats = subset.groupby("model")[metric_col].median().sort_values(ascending=True)
        ordered_methods = method_stats.index.tolist()
        subset["model"] = pd.Categorical(subset["model"], categories=ordered_methods, ordered=True)

        # Violin plot
        sns.violinplot(
            data=subset,
            x="model",
            y=metric_col,
            ax=ax,
            inner="quartile",
            scale="area",
            width=0.5
        )

        # Line plot for group medians
        stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
        ax.plot(range(len(ordered_methods)), stat_values, marker='o', linestyle='--', color='black', label='Median')

        ax.set_title(f"{group}")
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
        ax.set_xlabel('')
        ax.set_ylim(*ylim)
        if idx != 0:
            ax.set_yticklabels([])
            ax.set_ylabel("")

    # Final layout and title
    plot_title = title or f"{metric_col} Distribution by Method (Grouped)"
    fig.suptitle(plot_title, fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    # plt.show()
    return fig

# %%
group_method_counts = nmi_df.groupby("group")["model"].nunique()
group_method_counts
# Out:
# group
# Baseline      5
# Geneformer    6
# Other         6
# scGPT         2
# Name: model, dtype: int64

# %%
group_method_counts.sort_values(ascending=False)
# Out:
# group
# Geneformer    6
# Other         6
# Baseline      5
# scGPT         2
# Name: model, dtype: int64

# %%
nmi_df[nmi_df.model=='scFoundation']
# Out:
#            model       NMI  group
# 20  scFoundation  0.714511  Other
# 21  scFoundation  0.676112  Other
# 22  scFoundation  0.711347  Other
# 23  scFoundation  0.693761  Other
# 24  scFoundation  0.712964  Other
# 25  scFoundation  0.732719  Other
# 26  scFoundation  0.717893  Other
# 27  scFoundation  0.703804  Other
# 28  scFoundation  0.699758  Other
# 29  scFoundation  0.711836  Other

# %%
fig = plot_metric_by_group_violin(nmi_df, metric_col="NMI", ylim=(0.0, 1.))
plt.savefig('./plots/nmi3.png', dpi=100)
# Out:
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
kNN_label_f1_macro = results_10_runs[['model', 'kNN_label_f1_macro', 'group']].copy()
kNN_label_f1_macro.columns= ['model', 'F1', 'group']

fig = plot_metric_by_group_violin(kNN_label_f1_macro, metric_col="F1", ylim=(0.0, 1.))
plt.savefig('./plots/kNN_label_f1_macro.png', dpi=100)
# Out:
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1845/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1845/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1845/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig = plot_metric_by_group_violin(ari_df, metric_col="ARI", ylim=(0.0, 1.))
plt.savefig('./plots/ari3.png', dpi=100)
# Out:
# /tmp/ipykernel_1806/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1806/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1806/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1806/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1806/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1806/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1806/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1806/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1806/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_1806/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_1806/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_1806/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig = plot_metric_by_group_violin(asw_df, metric_col="ASW", ylim=(0.48, .7))
plt.savefig('./plots/asw3.png', dpi=100)
# Out:
# /tmp/ipykernel_3809/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_3809/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_3809/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_3809/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_3809/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_3809/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_3809/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_3809/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_3809/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_3809/1882659638.py:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_3809/1882659638.py:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stat_values = subset.groupby("model")[metric_col].median()[ordered_methods].values
# /tmp/ipykernel_3809/1882659638.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
