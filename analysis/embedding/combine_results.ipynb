# %%
import pandas as pd

# %%
#TODO: re-run scGPT results
scgpt_metrics = pd.read_csv('/home/jupyter/sceval/analysis_uns/metrics_runs.csv')
# scgpt_metrics['method'] = 'scimiarity'
# scgpt_metrics['group'] = 'scimiarity'
scgpt_metrics = scgpt_metrics[scgpt_metrics['method'].isin(['scgpt','scgpt_cancer'])]
scgpt_metrics
# Out:
#           method  NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  \
# 20         scgpt           0.694494           0.699925   0.543034    0.983788
# 21         scgpt           0.696455           0.710770   0.541832    0.970261
# 22         scgpt           0.677054           0.621885   0.537469    0.963834
# 23         scgpt           0.695442           0.695780   0.537064    0.985317
# 24         scgpt           0.703970           0.652718   0.538642    0.970983
# 25         scgpt           0.691655           0.647659   0.542064    0.974693
# 26         scgpt           0.681078           0.675606   0.537629    0.964858
# 27         scgpt           0.693984           0.685710   0.538299    0.978565
# 28         scgpt           0.702780           0.708913   0.541008    0.961869
# 29         scgpt           0.711292           0.674724   0.541395    0.956222
# 30  scgpt_cancer           0.701323           0.709255   0.538142    0.982596
# ...

# %%
_10_runs_df  = pd.read_csv('./metrics/metrics_10_runs.csv')
_10_runs_df
# Out:
#           method  NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  \
# 0            hvg           0.623929           0.504672   0.506691    0.977224
# 1            hvg           0.661756           0.637854   0.506394    0.987633
# 2            hvg           0.566944           0.304677   0.506617    0.986227
# 3            hvg           0.678981           0.600340   0.507554    0.985124
# 4            hvg           0.569790           0.291233   0.507050    0.988255
# ..           ...                ...                ...        ...         ...
# 85  scfoundation           0.732734           0.641470   0.572355    0.988894
# 86  scfoundation           0.727844           0.647603   0.573923    0.992945
# 87  scfoundation           0.721546           0.620240   0.572846    0.992617
# 88  scfoundation           0.735540           0.647488   0.572648    0.984192
# 89  scfoundation           0.746754           0.666797   0.573666    0.990942
#
# ...

# %%
scimiarity_metrics = pd.read_csv('./metrics/scimiarity.csv')
scimiarity_metrics['method'] = 'scimiarity'
scimiarity_metrics['group'] = 'scimiarity'
scimiarity_metrics
# Out:
#    NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  ASW_batch  \
# 0           0.744579           0.593142   0.660594    0.940631   0.500622
# 1           0.736055           0.567434   0.659012    0.981589   0.500158
# 2           0.757886           0.592463   0.660530    0.946523   0.498861
# 3           0.759724           0.621653   0.661637    0.989618   0.499431
# 4           0.754180           0.605643   0.662376    0.987431   0.499497
# 5           0.751736           0.591089   0.659285    0.982938   0.498682
# 6           0.745941           0.591193   0.657771    0.940666   0.499342
# 7           0.734593           0.580973   0.660823    0.988149   0.499170
# 8           0.768763           0.623870   0.663003    0.990565   0.499609
# 9           0.759774           0.627816   0.661495    0.941153   0.499995
#
#    ASW_label/batch  PCR_batch   avg_bio      method       group
# 0         0.903169   0.025523  0.666105  scimiarity  scimiarity
# ...

# %%
cellplm_metrics = pd.read_csv('./metrics/cellplm.csv')
cellplm_metrics['method'] = 'cellplm'
cellplm_metrics['group'] = 'cellplm'
cellplm_metrics
# Out:
#    NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  ASW_batch  \
# 0           0.555624           0.373994   0.618308    0.807329   0.491255
# 1           0.564830           0.387498   0.618697    0.809863   0.492992
# 2           0.563177           0.381643   0.617819    0.807086   0.492602
# 3           0.560502           0.370177   0.613014    0.806663   0.492419
# 4           0.561621           0.377208   0.614563    0.809469   0.492292
# 5           0.561148           0.373930   0.617994    0.845114   0.492419
# 6           0.559625           0.375534   0.616482    0.808181   0.492151
# 7           0.560766           0.381815   0.616015    0.810473   0.492694
# 8           0.551656           0.369464   0.615176    0.812285   0.493225
# 9           0.563349           0.379399   0.616509    0.811370   0.491976
#
#    ASW_label/batch  PCR_batch   avg_bio   method    group
# 0         0.840414   0.019848  0.515975  cellplm  cellplm
# ...

# %%
_10_runs_df
# Out:
#           method  NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  \
# 0            hvg           0.623929           0.504672   0.506691    0.977224
# 1            hvg           0.661756           0.637854   0.506394    0.987633
# 2            hvg           0.566944           0.304677   0.506617    0.986227
# 3            hvg           0.678981           0.600340   0.507554    0.985124
# 4            hvg           0.569790           0.291233   0.507050    0.988255
# ..           ...                ...                ...        ...         ...
# 85  scfoundation           0.732734           0.641470   0.572355    0.988894
# 86  scfoundation           0.727844           0.647603   0.573923    0.992945
# 87  scfoundation           0.721546           0.620240   0.572846    0.992617
# 88  scfoundation           0.735540           0.647488   0.572648    0.984192
# 89  scfoundation           0.746754           0.666797   0.573666    0.990942
#
# ...

# %%
combined_results = pd.concat([_10_runs_df, scimiarity_metrics, cellplm_metrics, scgpt_metrics], axis=0)

# %%
combined_results
# Out:
#           method  NMI_cluster/label  ARI_cluster/label  ASW_label  graph_conn  \
# 0            hvg           0.623929           0.504672   0.506691    0.977224
# 1            hvg           0.661756           0.637854   0.506394    0.987633
# 2            hvg           0.566944           0.304677   0.506617    0.986227
# 3            hvg           0.678981           0.600340   0.507554    0.985124
# 4            hvg           0.569790           0.291233   0.507050    0.988255
# ..           ...                ...                ...        ...         ...
# 35  scgpt_cancer           0.703092           0.720722   0.539723    0.982860
# 36  scgpt_cancer           0.706388           0.678669   0.538861    0.985270
# 37  scgpt_cancer           0.708675           0.691362   0.538976    0.977174
# 38  scgpt_cancer           0.696593           0.690427   0.539011    0.974218
# 39  scgpt_cancer           0.691642           0.649032   0.538903    0.985233
#
# ...

# %%
combined_results.to_csv('./metrics/metrics_10_runs3.csv')
